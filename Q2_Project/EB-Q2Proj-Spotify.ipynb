# %% [markdown]
# # Q2 Project - Data Analysis in Python
# ## Spotify Songs
# ###### https://www.kaggle.com/datasets/joebeachcapital/30000-spotify-songs

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %% [markdown]
# ### Original Data Set

# %%
df = pd.read_csv("spotify_songs.csv")
df.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# ...

# %%
df['playlist_genre'].unique()
# Out:
# array(['pop', 'rap', 'rock', 'latin', 'r&b', 'edm'], dtype=object)

# %%
plt.scatter(df["track_popularity"], df["duration_ms"],color = "C7", alpha=0.03)

plt.title('Populatiry vs Duration')
plt.xlabel('Track popularity')
plt.ylabel('Duration in ms')
# Out:
# Text(0, 0.5, 'Duration in ms')

# %%
stats.pearsonr(df["track_popularity"], df["duration_ms"])
# Out:
# PearsonRResult(statistic=-0.14368234955875345, pvalue=5.841154652678036e-151)

# %% [markdown]
# ## The negative value represents a negative correlation between popularity and duration indicating that the shorter songs tend to be more popular. The p-value shows that there is very high confidence.

# %% [markdown]
# ### My Two Figures

# %%
fig, (ax1, ax2) = plt.subplots(2,1)
ax1.hist2d(df["track_popularity"], df["tempo"])
ax2.hist2d(df["track_popularity"], df["valence"])

plt.title("Popularity vs Tempo and Popularity vs Valence")
ax1.set_ylabel("Tempo")
ax1.set_xlabel("Track Popularity")
ax2.set_ylabel("Valence")
ax2.set_xlabel("Track Popularity")

fig.tight_layout()

# %%
# Out:
# /var/folders/df/69sl5c8946l8ky45q3gjssn00000gn/T/ipykernel_16034/1946166464.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('playlist_genre').mean()
#                 track_popularity  danceability    energy       key  loudness  \
# playlist_genre
# edm                    34.833526      0.655041  0.802476  5.352143 -5.427445
# latin                  47.026576      0.713287  0.708312  5.483996 -6.264455
# pop                    47.744870      0.639302  0.701028  5.318867 -6.315328
# r&b                    41.223532      0.670179  0.590934  5.400479 -7.864848
# rap                    43.215454      0.718353  0.650708  5.470936 -7.042269
# rock                   41.728338      0.520548  0.732813  5.209049 -7.588895
#
# ...

# %% [markdown]
# ## In conclusion, I found this data set and the graphs i created to go along with it very interesting. I discovered that the shorter a song is the more popular its likely to be, which is some very useful data that can be implimeted in real life from this Data set. Furthermore, being able to compare diffrent aspects of a song, such as tempo and valence, againts its popularity was very interesting to oberve and think about what it comes to the music I listen to myself.
