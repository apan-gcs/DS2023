# %% [markdown]
# "Inferences to be made off house price", 12/1/23
# Ronan Johnson,
# Data Science 2,
# Data: https://www.kaggle.com/datasets/yasserh/housing-prices-dataset
# In this project, I analyze a data set on housing prices from the eary 1900s and onwards, which means I am dealing with a large amount of data. To help analyze this data, I utilize the code and lessons we have learned in class to arrange it so that conclusions can be made from the data that we organized.

# %% [markdown]
# ### [1](#[1]-Simple-Breakdown-of-data)
# ### [2](#[2]-Scatter-Plot)
# ### [3](#[3]-Comparing-price-and-squarefeet.)
# ### [4](#[4]-Price-of-a-home-per-neighborhood)
# ### [5](#[5]-Correlation)
# ### [6](#[6]-Conclusion)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import binomtest
import scipy.stats as stats

# %%
df = pd.read_csv("Housing_Price_Dataset.csv")

# %% [markdown]
# ### [1] Simple Breakdown of data
# The code below provides a quick and easy breakdown of data, highlighting the columns I am woeking with

# %%
df
# Out:
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0            2126         4          1        Rural       1969  215355.283618
# 1            2459         3          2        Rural       1980  195014.221626
# 2            1860         2          1       Suburb       1970  306891.012076
# 3            2294         2          1        Urban       1996  206786.787153
# 4            2130         5          2       Suburb       2001  272436.239065
# ...           ...       ...        ...          ...        ...            ...
# 49995        1282         5          3        Rural       1975  100080.865895
# 49996        2854         2          2       Suburb       1988  374507.656727
# 49997        2979         5          3       Suburb       1962  384110.555590
# 49998        2596         5          2        Rural       1984  380512.685957
# 49999        1572         5          3        Rural       2011  221618.583218
#
# [50000 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['SquareFeet', 'Bedrooms', 'Bathrooms', 'Neighborhood', 'YearBuilt',
#        'Price'],
#       dtype='object')

# %% [markdown]
# ### [2] Scatter Plot
# Below is a simple scatter plot that shows the representation between when a house was built to its price.

# %%
fig, ax = plt.subplots()

ax.scatter(df["YearBuilt"], df["Price"], alpha=0.1)
ax.set_xlim(1960, 2000)
ax.set_title("Year Built vs Price")
ax.set_ylabel("Price")
ax.set_xlabel("Year")
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# ### [3] Comparing price and squarefeet.
# Below is two plots, one plottting square feet vs the year it was built, and the other plotting price vs year built. In both graphs, their plotted lines are very similar. With this information, you can make an inference on how the sqaure footage of a house has a driect relationshop with the price of the house.

# %%
fig3, (ax31, ax32) = plt.subplots(2)
fig3.tight_layout()
fig3.suptitle("The Avg. Price of a Home Compared to When it Was Built And The Avg. Square Footage of a Home Compared to When it Was Built ")
ax31.plot(df.groupby("YearBuilt").mean()["Price"])
ax32.plot(df.groupby("YearBuilt").mean()["SquareFeet"])
ax31.set_xlabel("Year Built")
ax31.set_ylabel("Mean Price")

ax32.set_ylabel("Square Feet")
ax32.set_xlabel("Year Built")
#df.plot(kind='line',x="YearBuilt",y="Price",ax=ax)
#df.plot(kind='line',x="Price",y="YearBuilt", color='red', ax=ax)

#plt.show()
# Out:
# /var/folders/9l/q1f9j89j7ng5vpqpgkjwyd8c0000gn/T/ipykernel_66295/537551906.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ax31.plot(df.groupby("YearBuilt").mean()["Price"])
# /var/folders/9l/q1f9j89j7ng5vpqpgkjwyd8c0000gn/T/ipykernel_66295/537551906.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ax32.plot(df.groupby("YearBuilt").mean()["SquareFeet"])
# Text(0.5, 23.52222222222222, 'Year Built')

# %% [markdown]
# ### [4] Price of a home per neighborhood
# Below is a histogram representing the average price of a home in each different type of neighborhood. One inference that could be made about this data set from the histogram is how unbalanced the datset is. If you were to take the average price of a urban homes, I am sure it would be larger than the average price of all rural homes. However, with this dataset, all avergae price values are the same, representing how clean this data is.

# %%
# Fig 4. Plot bar graph for various neighborhoods
Neighborhoods = ['Rural', 'Urban', 'Surburban']

fig4, ax4 = plt.subplots()

ax4.bar(Neighborhoods, df.groupby("Neighborhood").mean()["Price"])

# Format / Rotate labels
labels = ['Rural', 'Urban','Surburban']
ax4.set_xticklabels(labels, rotation=35, ha='right')

ax4.set_title("Avg. Price of home per neighborhood type")
ax4.set_ylabel("Average house Price")

ax4.set_ylim(200000, 240000)

plt.show()
# Out:
# /var/folders/9l/q1f9j89j7ng5vpqpgkjwyd8c0000gn/T/ipykernel_66295/566915868.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax4.set_xticklabels(labels, rotation=35, ha='right')

# %% [markdown]
# ### [5] Correlation
# This code calculates the Pearson correlation coefficient and a p-value to test for a linear relationship between the "Price" and "SquareFeet". It has been determined that due to the p-value being zero, the null hypothesis can be rejected

# %%
x = df["Price"]
y = df["SquareFeet"]

stats.pearsonr(x, y)
# Out:
# PearsonRResult(statistic=0.750719785670884, pvalue=0.0)

# %% [markdown]
# ### [6] Conclusion
# In conclusion, there is a lot of information to learn from these data sets. With the skills to organize this data into legible and easy to understand charts, I am able to make solid conclusions based off these charts. As I progress with my data analysis skills, I will be able to make better inferences, possibly even ones with a real world impact.
